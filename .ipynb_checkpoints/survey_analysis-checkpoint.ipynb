# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import itertools
import os

df = pd.read_csv("mock_survey_data.csv")

# --- Ensure Composite Columns ---
df['support_avg'] = df[['support_1', 'support_2', 'support_3']].mean(axis=1)
df['micro_avg'] = df[['micro_1', 'micro_2', 'micro_3']].mean(axis=1)
df['validation_avg'] = df[['validation_1', 'validation_2', 'validation_3']].mean(axis=1)
df['psych_safety_avg'] = df[['psych_safety_1', 'psych_safety_2']].mean(axis=1)

# --- Variables to Correlate ---
features = [
    'support_avg', 'micro_avg', 'validation_avg', 'psych_safety_avg',
    'inclusion', 'recognition', 'work_life_balance', 'resources_tools',
    'satisfaction', 'burnout', 'intent_to_stay', 'commitment',
    'self_rated_performance', 'competence_confidence', 'performance_score'
]

# --- Compute ALL Pairwise Spearman Correlations ---
pairs = list(itertools.combinations(features, 2))
correlation_table = []

for x_var, y_var in pairs:
    rho = df[[x_var, y_var]].corr(method='spearman').iloc[0, 1]
    correlation_table.append({
        'Var 1': x_var,
        'Var 2': y_var,
        'Spearman r': round(rho, 3)
    })
    plt.figure(figsize=(6, 4))
    sns.regplot(data=df, x=x_var, y=y_var, scatter_kws={'s': 20, 'alpha': 0.6})
    plt.title(f"{x_var} vs {y_var}\nSpearman r = {rho:.2f}")
    plt.xlabel(x_var)
    plt.ylabel(y_var)
    plt.tight_layout()
    plt.savefig(f"pairwise_correlation_plots/{x_var}_vs_{y_var}.png")
    plt.close()

# --- Create & Show DataFrame ---
corr_df = pd.DataFrame(correlation_table)
corr_df.to_csv("pairwise_correlation_values.csv", index=False)
pd.set_option('display.max_rows', None)       # show all rows
pd.set_option('display.max_columns', None)    # show all columns
pd.set_option('display.width', None)          # prevent line-wrapping
pd.set_option('display.max_colwidth', None)   # show full content in any column
display(corr_df.head(105))
# Out:
#                       Var 1                   Var 2  Spearman r
# 0               support_avg               micro_avg      -0.300
# 1               support_avg          validation_avg      -0.071
# 2               support_avg        psych_safety_avg      -0.108
# 3               support_avg               inclusion       0.128
# 4               support_avg             recognition       0.040
# 5               support_avg       work_life_balance      -0.077
# 6               support_avg         resources_tools       0.003
# 7               support_avg            satisfaction       0.020
# 8               support_avg                 burnout       0.064
# 9               support_avg          intent_to_stay      -0.161
# 10              support_avg              commitment      -0.093
# 11              support_avg  self_rated_performance      -0.024
# 12              support_avg   competence_confidence      -0.129
# 13              support_avg       performance_score      -0.107
# 14                micro_avg          validation_avg       0.106
# 15                micro_avg        psych_safety_avg       0.137
# 16                micro_avg               inclusion       0.050
# 17                micro_avg             recognition      -0.021
# 18                micro_avg       work_life_balance       0.023
# 19                micro_avg         resources_tools      -0.059
# 20                micro_avg            satisfaction      -0.107
# 21                micro_avg                 burnout       0.094
# 22                micro_avg          intent_to_stay       0.288
# 23                micro_avg              commitment      -0.116
# 24                micro_avg  self_rated_performance      -0.145
# 25                micro_avg   competence_confidence      -0.086
# 26                micro_avg       performance_score       0.154
# 27           validation_avg        psych_safety_avg       0.174
# 28           validation_avg               inclusion       0.083
# 29           validation_avg             recognition       0.033
# 30           validation_avg       work_life_balance      -0.078
# 31           validation_avg         resources_tools       0.039
# 32           validation_avg            satisfaction      -0.080
# 33           validation_avg                 burnout      -0.087
# 34           validation_avg          intent_to_stay      -0.011
# 35           validation_avg              commitment       0.250
# 36           validation_avg  self_rated_performance      -0.238
# 37           validation_avg   competence_confidence       0.064
# 38           validation_avg       performance_score       0.193
# 39         psych_safety_avg               inclusion       0.079
# 40         psych_safety_avg             recognition       0.090
# 41         psych_safety_avg       work_life_balance       0.171
# 42         psych_safety_avg         resources_tools      -0.216
# 43         psych_safety_avg            satisfaction      -0.016
# 44         psych_safety_avg                 burnout       0.138
# 45         psych_safety_avg          intent_to_stay      -0.024
# 46         psych_safety_avg              commitment       0.003
# 47         psych_safety_avg  self_rated_performance       0.057
# 48         psych_safety_avg   competence_confidence       0.004
# 49         psych_safety_avg       performance_score       0.075
# 50                inclusion             recognition       0.071
# 51                inclusion       work_life_balance      -0.063
# 52                inclusion         resources_tools      -0.001
# 53                inclusion            satisfaction      -0.161
# 54                inclusion                 burnout       0.109
# 55                inclusion          intent_to_stay       0.076
# 56                inclusion              commitment       0.055
# 57                inclusion  self_rated_performance      -0.105
# 58                inclusion   competence_confidence      -0.385
# 59                inclusion       performance_score      -0.038
# 60              recognition       work_life_balance      -0.220
# 61              recognition         resources_tools      -0.016
# 62              recognition            satisfaction       0.173
# 63              recognition                 burnout       0.148
# 64              recognition          intent_to_stay       0.019
# 65              recognition              commitment       0.034
# 66              recognition  self_rated_performance      -0.069
# 67              recognition   competence_confidence       0.107
# 68              recognition       performance_score       0.048
# 69        work_life_balance         resources_tools       0.025
# 70        work_life_balance            satisfaction      -0.038
# 71        work_life_balance                 burnout      -0.093
# 72        work_life_balance          intent_to_stay      -0.004
# 73        work_life_balance              commitment      -0.055
# 74        work_life_balance  self_rated_performance       0.115
# 75        work_life_balance   competence_confidence      -0.067
# 76        work_life_balance       performance_score      -0.030
# 77          resources_tools            satisfaction      -0.032
# 78          resources_tools                 burnout      -0.096
# 79          resources_tools          intent_to_stay      -0.082
# 80          resources_tools              commitment       0.029
# 81          resources_tools  self_rated_performance       0.006
# 82          resources_tools   competence_confidence      -0.069
# 83          resources_tools       performance_score      -0.087
# 84             satisfaction                 burnout       0.002
# 85             satisfaction          intent_to_stay      -0.004
# 86             satisfaction              commitment      -0.076
# 87             satisfaction  self_rated_performance       0.053
# 88             satisfaction   competence_confidence       0.158
# 89             satisfaction       performance_score      -0.120
# 90                  burnout          intent_to_stay      -0.002
# 91                  burnout              commitment      -0.177
# 92                  burnout  self_rated_performance       0.003
# 93                  burnout   competence_confidence       0.051
# 94                  burnout       performance_score      -0.049
# 95           intent_to_stay              commitment      -0.102
# 96           intent_to_stay  self_rated_performance       0.015
# 97           intent_to_stay   competence_confidence       0.102
# 98           intent_to_stay       performance_score       0.004
# 99               commitment  self_rated_performance       0.041
# 100              commitment   competence_confidence      -0.020
# 101              commitment       performance_score       0.160
# 102  self_rated_performance   competence_confidence       0.084
# 103  self_rated_performance       performance_score       0.005
# 104   competence_confidence       performance_score       0.195
